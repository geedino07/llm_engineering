# %% [markdown]
# # End of week 1 exercise Solution comparing two LLM's with a third LLM
#
# Compare and contrast the difference response between two models when asked a technical question using a third LLM
#
# This notebook demonstrates how to compare the responses of two local Large Language Models (LLMs) using Deepseek.

# %%
# Imports

import ollama
from IPython.display import Markdown, display

# %%
# Constants

MODEL_Phi3 = 'phi3:latest'
MODEL_LLAMA1b = "llama3.2:1b"
MODEL_DEEPSEEK = "deepseek-r1:1.5b"

# %%
# Environment

system_prompt = """
You are an assistant that takes a technical question and respond with an explanation.
"""

question = """
please explain the difference between quantization and tokenization
"""


user_prompt = """
Answer the question in detail but keep it:

- Brief
- Bullet points
- Concise
- Maximum 300 words

Question:
""" + question

def message():
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}
    ]

# %%
def get_phi3_response():
    response = ollama.chat(
        model=MODEL_Phi3,
        messages=message()
    )

    return response['message']['content']


def get_llama_response():
    response = ollama.chat(
        model=MODEL_LLAMA1b,
        messages=message()
    )

    return response['message']['content']

# %%
#function to compare the two models

def compare_models():
    phi_response = get_phi3_response()
    llama_response = get_llama_response()

    # Display Model A Response
    display(Markdown("## Response A — Phi3\n"))
    display(Markdown(phi_response))

    # Display Model B Response
    display(Markdown("\n---\n"))
    display(Markdown("## Response B — Llama 3.2 1B\n"))
    display(Markdown(llama_response))


    comparison_prompt = f"""
    You are evaluating two LLM responses to the same technical question.

    Response A (Phi3):
    {phi_response}

    Response B (Llama 3.2 1B):
    {llama_response}

    Do the following:
    1. List similarities
    2. List differences
    3. Compare technical depth
    4. Compare clarity
    5. Compare correctness
    6. Recommend which model performed better and why

    Be structured and objective.
    """

    evaluation = ollama.chat(
        model=MODEL_DEEPSEEK,   # you can also use llama here
        messages=[{"role": "user", "content": comparison_prompt}]
    )

    display(Markdown("\n---\n"))
    display(Markdown("## Model Evaluation\n"))
    display(Markdown(evaluation['message']['content']))

# %% [markdown]
# Execute function to compare the Phi3 and Ollama models using Deepseek

# %%
compare_models()
# Out:
# ## Response A — Phi3
# Quantization vs Tokenization
#
# - **Concept**: Quantization involves converting continuous or large discrete variable sets into a smaller set of representational levels, often in signal processing. Tokenization is about breaking text down into units (tokens) for natural language processing tasks like translation or summarizing.
#
# - **Application Area**:
#   - Signal Processing and Machine Learning Models: Used to reduce the size of neural networks by mapping input variables/features onto a smaller set, which helps in deploying models on resource-constrained devices while retaining accuracy. Quantization often involves both scalar quantization for individual values as well as vector quantization across multiple dimensions or channels (like audio and video streams).
#
#   - NLP: Employed primarily during preprocessing of text data to convert unstructured raw text into structured tokens, such as words, phrases, or punctuation marks. It aids in simplifying the complexity for algorithms that analyze language patterns but does not involve numerical conversion like quantization.
#
# - **Purpose**:
#   - The aim of Quantization is to optimize model size and speed without significantly affecting performance by reducing precision, making it easier to deploy models on edge devices or in environments where computing power is limited. It’s a form of lossy compression technique that' extrinsically reduces the bit-rate for storage and transmission with minimal impact on output fidelity.
#
#   - Tokenization serves as an essential step toward understanding language structure, facilitating tasks such as sentiment analysis or machine translation by representing text in tokens which algorithms can process systematically without interpreting semantics directly—just identifying segments of the input string that represent meaningful units for further processing like parsing and syntax-based analyses.
#
# - **Effect on Data**:
#   - Quantization leads to a lossy transformation, where some data fidelity might be sacrificed due to reduced precision in representation which is often acceptable if the overall performance remains within an acceptable range for most applications. It's critical when dealing with continuous or very high-resolution signals that need efficient processing and storage capabilities.
#
#   - Tokenization maintains original text integrity, transforming it into a format where linguistic elements are identifiable but disconnected from the semantic content; this preserves information necessary for understanding syntax over semantics without affecting numerical data representation fidelity as in quantization processes.
# ---
# ## Response B — Llama 3.2 1B
# **Quantization vs Tokenization**
#
# Quantization and tokenization are two fundamental concepts in natural language processing (NLP). While they are related, they have distinct meanings.
#
# * **Tokenization**: This is the process of breaking down a sentence or phrase into individual units, such as words, subwords, or tokens. Tokens can be separated by spaces, punctuation, or other delimiters.
# 	+ Examples:
# 		- "This is an example sentence."
# 		- "The quick brown fox jumps over the lazy dog."
# * **Quantization**: This refers to a specific type of tokenization where each word is represented using its most similar vector representation in a dictionary. The goal is to minimize distortion between words and improve downstream NLP tasks.
# 	+ Key differences:
# 		- Tokenization is a general process, while quantization focuses on the representation of individual tokens.
# 		- Quantization aims to preserve the semantic meaning of words, whereas tokenization may not necessarily capture word relationships or context.
#
# In summary:
#
# * Tokenization breaks down text into individual units (tokens).
# * Quantization represents each token using its most similar vector representation in a dictionary.
# ---
# ## Model Evaluation
# **Evaluation of Quantization vs Tokenization Responses (LLM) for a Technical Question**
#
# **1. Similarities:**
# - Both responses discuss key concepts ("quantization" and "tokenization") and their roles in NLP tasks.
# - Tokenization is a broader tool that includes sentiment analysis, while quantization is specific to word representation.
#
# **2. Differences:**
# - **Tokenization:** A general approach for breaking text into units (words, phrases).
# - **Quantization:** Specific tokenization where each word is represented as a vector, aiming to preserve semantic meaning without fidelity loss.
# - **Effect on Data:** Tokenization preserves original text integrity, while quantization introduces data fidelity loss.
#
# **3. Technical Depth:**
# - Response A provides more detailed technical explanations for quantization's signal processing applications and broader context.
# - Response B is concise with an example from Llama but still covers core concepts succinctly.
#
# **4. Clarity:**
# - Both responses are clear, explaining both the concept and its application effectively.
#
# **5. Correctness:**
# - Both definitions are accurate; Response A adds technical details to quantization's applications.
#
# **Recommendation:**
# - **Response A:** More detailed in explaining quantization's methods and broader impact.
# - **Response B:** Concise with a specific example from Llama, but still clear on tokenization and its purpose.
#
# **Conclusion:**
# The recommendation depends on the audience and technical background. Response A excels for deeper technical understanding of quantization, while Response B is excellent for a straightforward explanation. Both are valuable depending on their intended use cases.
